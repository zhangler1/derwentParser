# %%
import pandas as pd

# %%
import matplotlib.pyplot as pl

# %%
ae=pd.read_csv("sarswashed.csv",index_col=0)
ae.head()
# Out:
#                                                Title     PatentNumber  \
# 0   SYSTEM OF STATION TWO-WAY PARK COMMUNICATION ...     RU2711479-C1
# 1   Determining autophagic flux, involves determi...  WO2020003286-A1
# 2   Creating cell-stored barcoded deep mutational...  WO2020006494-A1
# 3   New modified oligonucleotide that binds to ta...  WO2019240504-A1
# 5   Treating or preventing viral infection e.g. h...  WO2019222349-A1
#
#   nationality                                            ipcTOP3  \
# 0          RU                                    ['B61L-023/00']
# 1          WO  ['TION - INDEPENDENT CLAIMS are included for t...
# 2          WO  ['TION - INDEPENDENT CLAIMS are included for t...
# 3          WO  ['TION - Modified oligonucleotide that binds t...
# 5          WO  ['TION - Method (M1) for treating or preventin...
#
#                                              authors  \
# 0  ['BALANDIN V I', 'BLINDER I D', 'DURENKOV A V'...
# ...

# %%
ae.ipcTOP3=ae.ipcTOP3[:,0]
ae
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-abbac04f8e4e> in <module>
# ----> 1 ae.ipcTOP3=ae.ipcTOP3[:,0]
#       2 ae
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     808             key = check_bool_indexer(self.index, key)
#     809
# --> 810         return self._get_with(key)
#     811
#     812     def _get_with(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     821             if isinstance(key, tuple):
#     822                 try:
# --> 823                     return self._get_values_tuple(key)
#     824                 except Exception:
#     825                     if len(key) == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_values_tuple(self, key)
#     866
# ...

# %%
ae.groupby("PatentAsignee").describe(include="object")
# Out:
#                                                    PatentNumber         \
#                                                           count unique
# PatentAsignee
#  302 HOSPITAL PLA (THRE-Non-standard)                         1      1
#  3M INNOVATIVE PROPERTIES CO (MINN-C)                         4      4
#  AARON DIAMOND AIDS RES CENT (AARO-Non-standard)              1      1
#  AB SCI (ABSC-C)                                              1      1
#  ACAD MILITARY MEDICAL SCI PLA (JSYX-C)                       1      1
#  ACAD SINICA (SNIC-C)                                         2      2
#  ACAMBIS INC (ACAM-Non-standard)                              1      1
#  ACORN ENG CO (ACOR-Non-standard)                             1      1
#  ADALTIS INC (ADAL-Non-standard)                              1      1
#  ADMARK HEALTHCARE LLC (ADMA-Non-standard)                    1      1
#  ADVANCED INHALATION THERAPIES AIT LTD (ADIN-No...            1      1
# ...
