# %%
import pandas as pd
import numpy as np

# %%
D:\Download\derwentParser\output\machinepatAEs.csv
D:\Download\derwentParser\output\machinepatAUs.csv
D:\Download\derwentParser\output\machinepatents.csv
D:\Download\derwentParser\output\machinepatIPCs.csv
D:\Download\derwentParser\output\machinepatNations.csv

# %%
pat=pd.read_csv("output\machinepatents.csv",index_col=0)
pat.head(4)
# Out:
#                                                Title     PatentNumber  \
# 0   Method for tracking motion of rigid portion o...  US2020121954-A1
# 1   Valve for use in hydraulic system, has piston...    US10626892-B1
# 2   Continuous-action excavating machine hydrauli...     RU2719295-C1
# 3   System for monitoring, testing and controllin...  WO2020077281-A1
#
#    publishDate language  pages region
# 0       2020.0  English    1.0  World
# 1       2020.0  English    0.0  World
# 2       2020.0  Russian    1.0  World
# 3       2020.0  English    9.0  World

# %%
# Out:
# Title           75500
# PatentNumber    75500
# publishDate     75499
# language        73690
# pages           74265
# region          75500
# dtype: int64

# %%
pat.drop_duplicates(subset="PatentNumber",keep="first",inplace=True)

# %%
pat.count()
# Out:
# Title           75492
# PatentNumber    75492
# publishDate     75491
# language        73682
# pages           74257
# region          75492
# dtype: int64

# %%
pat.drop_duplicates(subset="PatentNumber",keep="first",inplace=True)

pat.groupby(by="publishDate").count()
pat.isnull().sum()
# Out:
# Title              0
# PatentNumber       0
# publishDate        1
# language        1810
# pages           1235
# region             0
# dtype: int64

# %%
pat.dropna(subset=["publishDate"],inplace=True )
pat.dropna(subset=["ipcTOP3"],inplace=True)
pat.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-50e794f65f01> in <module>
#       1 pat.dropna(subset=["publishDate"],inplace=True )
# ----> 2 pat.dropna(subset=["ipcTOP3"],inplace=True)
#       3 pat.isnull().sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4283                 check = indices == -1
#    4284                 if check.any():
# -> 4285                     raise KeyError(list(np.compress(check, subset)))
#    4286                 agg_obj = self.take(indices, axis=agg_axis)
#    4287
#
# KeyError: ['ipcTOP3']

# %%
pat.to_csv("output\patents2.csv",index=False)

# %%
pae=pd.read_csv("output\patAEs.csv",index_col=0)
pae.drop_duplicates(keep="first",inplace=True
                   )
pae.isnull().sum()
# Out:
# PatentNumber     0
# PatentAsignee    0
# dtype: int64

# %%
pae.to_csv("output\patAEs2.csv",index=False)

# %%
