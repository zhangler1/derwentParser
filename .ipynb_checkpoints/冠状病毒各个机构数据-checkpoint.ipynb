# %%
import pandas as pd

# %%
import matplotlib.pyplot as pl

# %%
pd.read_csv("sarswashed.csv",index_col=0)
# Out:
#                                                   Title     PatentNumber  \
# 0      SYSTEM OF STATION TWO-WAY PARK COMMUNICATION ...     RU2711479-C1
# 1      Determining autophagic flux, involves determi...  WO2020003286-A1
# 2      Creating cell-stored barcoded deep mutational...  WO2020006494-A1
# 3      New modified oligonucleotide that binds to ta...  WO2019240504-A1
# 5      Treating or preventing viral infection e.g. h...  WO2019222349-A1
# 6      Plasma emitting diode device for use in e.g. ...   KR2019128127-A
# 7      Sensor chip for protecting respiratory system...     KR2044863-B1
# 8      Joint observation multiple MIMO-SARs based th...    CN110441770-A
# 9      Facial mask for filtering harmful viruses cau...     KR2026892-B1
# 10     Composition used in drug to treat influenza a...  WO2019203697-A1
# 11     Recovery, treatment, or prevention of cancer,...  WO2019199673-A1
# 12     Detecting infection in subject involves assay...  WO2019197833-A1
# ...

# %%
pd.read_csv?
